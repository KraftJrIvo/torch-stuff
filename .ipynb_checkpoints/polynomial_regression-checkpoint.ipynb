# %%
import torch
import numpy as np
import math
import matplotlib.pyplot as plt
from IPython.display import display
# %matplotlib inline

def dataset(n=100):
    xs = []
    ys = []
    for i in range(n):
        x = i * 4 / n
        xs.append(x)
        #ys.append(math.sin(x))
        #ys.append(x)
        ys.append(abs(x - 2))
    return torch.tensor(xs), torch.tensor(ys)

def plot(once, fig, hdisplay, ax1, ax2, xs_train, ys_train, xs_test, ys_test, epochs, train_losses, test_losses):    
    ax1.clear()
    ax2.clear()
    if once:
        ax1.set_xlabel('x')
        ax1.set_ylabel('y')
        ax1.set_title('inference')
        ax1.title.set_fontsize(9)
        ax2.set_xlabel('Epoch')
        ax2.set_ylabel('Loss')
        ax2.set_title('Training Loss')
        ax1.scatter(xs_train, ys_train, c='g', label='Training Data')
        ax1.scatter(xs_test, ys_test, c='b', label='Result')
        ax2.plot(epochs, train_losses, c='g', label='Training Loss')
        ax2.plot(epochs, test_losses, c='b', label='Test Loss')
    else:
        ax1.scatter(xs_train, ys_train, c='g', label='Training Data')
        ax1.scatter(xs_test, ys_test, c='b', label='Result')
        ax2.plot(epochs, train_losses, c='g', label='Training Loss')
        ax2.plot(epochs, test_losses, c='b', label='Test Loss')
    hdisplay.update(fig)

class PolynomialRegressionModel(torch.nn.Module):
    def __init__(self, n_powers):
        super().__init__()
        self.n_powers = n_powers
        self.coeffs = torch.nn.Parameter(torch.rand(n_powers, requires_grad=True))
        
    def forward(self, x):
        return torch.sum(torch.mul(torch.pow(x.repeat(self.n_powers, 1), torch.arange(0,self.n_powers).reshape(1,-1).t()), self.coeffs.reshape(1,-1).t()), 0)

# creating dataset
xs_train, ys_train = dataset(100)
xs_test, ys_test = dataset(23)

# creating model
POWERS = 5
torch.manual_seed(42)
model = PolynomialRegressionModel(POWERS)

# creating optimizer
optimizer = torch.optim.Adam(params = model.parameters())

# for plotting
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
hdisplay = display("", display_id=True)

# train preparation
loss_fn = torch.nn.L1Loss()
EPOCHS = 10000
epochs = []
train_losses = []
test_losses = []
for epoch in range(EPOCHS):
    # train step
    model.train()
    ys_pred = model(xs_train)
    loss = loss_fn(ys_pred, ys_train)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # test evaluation
    model.eval()
    with torch.inference_mode():
        test_pred = model(xs_test)
        test_loss = loss_fn(test_pred, ys_test)
        # for plotting
        if epoch % (EPOCHS / 100) == 0:
            epochs.append(epoch)
            train_losses.append(loss.item())
            test_losses.append(test_loss.item())
            plot(epoch == 0, fig, hdisplay, ax1, ax2, xs_train, ys_train, xs_test, test_pred, epochs, train_losses, test_losses)
            print(f'Epoch: {epoch} | train loss: {round(loss.item(), 6)} | test loss: {round(test_loss.item(), 6)}')
# Out:
# Epoch: 0 | train loss: 0.713977 | test loss: 0.716755
# Epoch: 100 | train loss: 0.415981 | test loss: 0.425455
# Epoch: 200 | train loss: 0.294749 | test loss: 0.302156
# Epoch: 300 | train loss: 0.272477 | test loss: 0.278404
# Epoch: 400 | train loss: 0.251407 | test loss: 0.256623
# Epoch: 500 | train loss: 0.227903 | test loss: 0.232643
# Epoch: 600 | train loss: 0.202179 | test loss: 0.206336
# Epoch: 700 | train loss: 0.174516 | test loss: 0.178048
# Epoch: 800 | train loss: 0.145144 | test loss: 0.148017
# Epoch: 900 | train loss: 0.114254 | test loss: 0.116434
# Epoch: 1000 | train loss: 0.082012 | test loss: 0.083473
# Epoch: 1100 | train loss: 0.048562 | test loss: 0.04928
# Epoch: 1200 | train loss: 0.014032 | test loss: 0.013984
# Epoch: 1300 | train loss: 0.000338 | test loss: 0.000129
# Epoch: 1400 | train loss: 8e-06 | test loss: 0.000912
# Epoch: 1500 | train loss: 0.000322 | test loss: 1.2e-05
# Epoch: 1600 | train loss: 0.000293 | test loss: 0.00043
# Epoch: 1700 | train loss: 0.000363 | test loss: 0.000525
# Epoch: 1800 | train loss: 0.000528 | test loss: 0.000268
# Epoch: 1900 | train loss: 0.000266 | test loss: 0.000336
# Epoch: 2000 | train loss: 0.000338 | test loss: 0.000478
# Epoch: 2100 | train loss: 0.000469 | test loss: 0.000237
# Epoch: 2200 | train loss: 0.000243 | test loss: 0.000307
# Epoch: 2300 | train loss: 0.000313 | test loss: 0.000443
# Epoch: 2400 | train loss: 0.00044 | test loss: 0.000223
# Epoch: 2500 | train loss: 0.000229 | test loss: 0.000291
# Epoch: 2600 | train loss: 0.000298 | test loss: 0.000422
# Epoch: 2700 | train loss: 0.000424 | test loss: 0.000215
# Epoch: 2800 | train loss: 0.00022 | test loss: 0.000282
# Epoch: 2900 | train loss: 0.000289 | test loss: 0.000409
# Epoch: 3000 | train loss: 0.000411 | test loss: 0.000208
# Epoch: 3100 | train loss: 0.000217 | test loss: 0.000274
# Epoch: 3200 | train loss: 0.000284 | test loss: 0.000402
# Epoch: 3300 | train loss: 0.000403 | test loss: 0.000204
# Epoch: 3400 | train loss: 0.000213 | test loss: 0.00027
# Epoch: 3500 | train loss: 0.00028 | test loss: 0.000396
# Epoch: 3600 | train loss: 0.000398 | test loss: 0.000202
# Epoch: 3700 | train loss: 0.000211 | test loss: 0.000267
# Epoch: 3800 | train loss: 0.000278 | test loss: 0.000392
# Epoch: 3900 | train loss: 0.000395 | test loss: 0.0002
# Epoch: 4000 | train loss: 0.00021 | test loss: 0.000264
# Epoch: 4100 | train loss: 0.000275 | test loss: 0.000389
# Epoch: 4200 | train loss: 0.000392 | test loss: 0.000198
# Epoch: 4300 | train loss: 0.000208 | test loss: 0.000263
# Epoch: 4400 | train loss: 0.000274 | test loss: 0.000387
# Epoch: 4500 | train loss: 0.00039 | test loss: 0.000197
# Epoch: 4600 | train loss: 0.000207 | test loss: 0.000262
# Epoch: 4700 | train loss: 0.000273 | test loss: 0.000386
# Epoch: 4800 | train loss: 0.000389 | test loss: 0.000197
# Epoch: 4900 | train loss: 0.000207 | test loss: 0.00026
# Epoch: 5000 | train loss: 0.000273 | test loss: 0.000385
# Epoch: 5100 | train loss: 0.000387 | test loss: 0.000195
# Epoch: 5200 | train loss: 0.000206 | test loss: 0.000261
# Epoch: 5300 | train loss: 0.000274 | test loss: 0.000386
# Epoch: 5400 | train loss: 0.000385 | test loss: 0.000194
# Epoch: 5500 | train loss: 0.000205 | test loss: 0.000261
# Epoch: 5600 | train loss: 0.000272 | test loss: 0.000384
# Epoch: 5700 | train loss: 0.000385 | test loss: 0.000195
# Epoch: 5800 | train loss: 0.000207 | test loss: 0.000258
# Epoch: 5900 | train loss: 0.000273 | test loss: 0.000385
# Epoch: 6000 | train loss: 0.000382 | test loss: 0.000192
# Epoch: 6100 | train loss: 0.000209 | test loss: 0.000256
# Epoch: 6200 | train loss: 0.000274 | test loss: 0.000385
# Epoch: 6300 | train loss: 0.000385 | test loss: 0.000195
# Epoch: 6400 | train loss: 0.000205 | test loss: 0.000259
# Epoch: 6500 | train loss: 0.000271 | test loss: 0.000383
# Epoch: 6600 | train loss: 0.000385 | test loss: 0.000195
# Epoch: 6700 | train loss: 0.000201 | test loss: 0.000263
# Epoch: 6800 | train loss: 0.000266 | test loss: 0.000378
# Epoch: 6900 | train loss: 0.000391 | test loss: 0.0002
# Epoch: 7000 | train loss: 0.0002 | test loss: 0.000264
# Epoch: 7100 | train loss: 0.000269 | test loss: 0.00038
# Epoch: 7200 | train loss: 0.000383 | test loss: 0.000193
# Epoch: 7300 | train loss: 0.000207 | test loss: 0.000257
# Epoch: 7400 | train loss: 0.000274 | test loss: 0.000385
# Epoch: 7500 | train loss: 0.000379 | test loss: 0.000189
# Epoch: 7600 | train loss: 0.000215 | test loss: 0.000249
# Epoch: 7700 | train loss: 0.000284 | test loss: 0.000395
# Epoch: 7800 | train loss: 0.000369 | test loss: 0.000179
# Epoch: 7900 | train loss: 0.000221 | test loss: 0.000244
# Epoch: 8000 | train loss: 0.000286 | test loss: 0.000397
# Epoch: 8100 | train loss: 0.000369 | test loss: 0.000179
# Epoch: 8200 | train loss: 0.000221 | test loss: 0.000244
# Epoch: 8300 | train loss: 0.00029 | test loss: 0.0004
# Epoch: 8400 | train loss: 0.000362 | test loss: 0.000172
# Epoch: 8500 | train loss: 0.000232 | test loss: 0.000232
# Epoch: 8600 | train loss: 0.000301 | test loss: 0.000412
# Epoch: 8700 | train loss: 0.00035 | test loss: 0.000161
# Epoch: 8800 | train loss: 0.000244 | test loss: 0.000221
# Epoch: 8900 | train loss: 0.000313 | test loss: 0.000423
# Epoch: 9000 | train loss: 0.000338 | test loss: 0.000149
# Epoch: 9100 | train loss: 0.000255 | test loss: 0.000211
# Epoch: 9200 | train loss: 0.00032 | test loss: 0.00043
# Epoch: 9300 | train loss: 0.000335 | test loss: 0.000146
# Epoch: 9400 | train loss: 0.000255 | test loss: 0.000211
# Epoch: 9500 | train loss: 0.00032 | test loss: 0.00043
# Epoch: 9600 | train loss: 0.000335 | test loss: 0.000146
# Epoch: 9700 | train loss: 0.000252 | test loss: 0.000213
# Epoch: 9800 | train loss: 0.000314 | test loss: 0.000423
# Epoch: 9900 | train loss: 0.000345 | test loss: 0.000157
